# %% [markdown]
# **The Sunshine Vitamin: Vitamin D Deficiency & SAD**

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([80, 10, 10])
mylabels = ["Sunlight", "Diet", "Other"]
myexplode = [0.2, 0, 0, 0]
mycolors = [ "#E9C46A", "#F4A261","#E76F51"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.legend(title = "Sources of Vitamin D")
plt.show()
